# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import datetime

# %%
data=pd.read_csv(r"C:\Users\Rani\Desktop\COVID-19 REAL PROJECT\COVID-19_DATA.csv")

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data.tail()
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       321 non-null    object
#  1   State      140 non-null    object
#  2   Region     321 non-null    object
#  3   Confirmed  321 non-null    int64
#  4   Deaths     321 non-null    int64
#  5   Recovered  321 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 15.2+ KB

# %%
data.describe()
# Out:
#            Confirmed        Deaths      Recovered
# count     321.000000    321.000000     321.000000
# mean     9949.800623    709.152648    3030.277259
# std     31923.853086   3236.162817   14364.870365
# min         0.000000      0.000000       0.000000
# 25%       104.000000      2.000000       2.000000
# 50%       653.000000     12.000000      73.000000
# 75%      4655.000000    144.000000     587.000000
# max    299691.000000  27682.000000  132929.000000

# %%
vaccine_data = pd.read_csv(r"C:\Users\Rani\Desktop\COVID-19 REAL PROJECT\COVID_Vaccine_Statewise.csv")

# %%
vaccine_data.head(2)
# Out:
#                 States  First_Dose  Second_Dose
# 0  Andaman And Nicobar      294001       200157
# 1       Andhra Pradesh    32976969     20375181

# %%
vaccine_data.drop(["Sr.No"],inplace = True , axis = 1)

# %%
vaccine_data
# Out:
#                                       States  First_Dose  Second_Dose
# 0                        Andaman And Nicobar      294001       200157
# 1                             Andhra Pradesh    32976969     20375181
# 2                          Arunachal Pradesh      771875       534486
# 3                                      Assam    20172463      8068795
# 4                                      Bihar    49874828     18346781
# 5                                 Chandigarh      926035       546981
# 6                               Chhattisgarh    14851682      7343273
# 7   Dadra And Nagar Haveli And Daman And Diu      660753       370255
# 8                                      Delhi    13055636      7425404
# 9                                        Goa     1262568       911114
# 10                                   Gujarat    44735217     25972387
# 11                                   Haryana    17772376      8115463
# ...

# %%
data # change the format of date column
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data['Date'] = pd.to_datetime(data['Date'], format='%Y-%m-%d')

# %%
data.head(5)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0 2020-04-29   NaN  Afghanistan       1939      60        252
# 1 2020-04-29   NaN      Albania        766      30        455
# 2 2020-04-29   NaN      Algeria       3848     444       1702
# 3 2020-04-29   NaN      Andorra        743      42        423
# 4 2020-04-29   NaN       Angola         27       2          7

# %%
#how to find the total number of Active cases 
data['Active_Cases'] =data['Confirmed'] -(data['Recovered'] + data['Deaths'])
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered  \
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
#      Active_Cases
# 0            1627
# 1             281
# 2            1702
# 3             278
# ...

# %%
data = pd.read_csv("C:\\Users\\Rani\\Desktop\\COVID-19 REAL PROJECT\\COVID-19_DATA.csv")

# %%
#how to create a pivot table 
statewise =pd.pivot_table(data,values =["Confirmed","Deaths","Recovered"],index = "State",aggfunc = max )

# %%
statewise["Recovery Rate"] = statewise["Recovered"]*100/statewise["Confirmed"]

# %%
statewise["Mortality Rate"] =statewise ["Deaths"]*100/statewise["Confirmed"]

# %%
statewise = statewise.sort_values(by = "Confirmed",ascending = False)

# %%
statewise.style.background_gradient(cmap="cubehelix")
# Out:
# <style type="text/css">
# #T_be02d_row0_col0, #T_be02d_row0_col1, #T_be02d_row110_col4, #T_be02d_row136_col2 {
#   background-color: #ffffff;
#   color: #000000;
# }
# ...

# %%
# top 10 Active casese
top_10_active_cases =data .groupby(by = "State").max()[["Active_Cases","Date"]].sort_values(by = ["Active_Cases"],ascending = False).reset_index()
fig =plt.figure(figsize=(16,9))
plt.title("Top 10 States with most Active Cases in India",size = 25)
ax = sns.barplot(data = top_10_active_cases.iloc[:10], y = "Active_Cases", x= "State",linewidth = 2, edgecolor= "red")
plt.xlabel("State")
plt.ylabel("Total Active Cases")
plt.show()

# %%
#Top states with highest deaths 
top_10_deaths =data.groupby(by = "State").max()[["Deaths","Date"]].sort_values(by = ["Deaths"],ascending = False).reset_index()
fig =plt.figure(figsize=(12,5))
plt.title("Top 10 States with most Deaths Cases",size = 25)
ax = sns.barplot(data = top_10_deaths.iloc[:12], y = "Deaths", x= "State",linewidth = 2, edgecolor= "black")
plt.xlabel("State")
plt.ylabel("Total Deaths Cases")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'data' is your DataFrame conStatetaining the necessary data

# Filter data for the specified states
states_of_interest = ["New York", "New Jersey", "Hubei", "Massachusetts", "Illinois"]
filtered_data = data[data["State"].isin(states_of_interest)]

# Create the scatter plot
plt.figure(figsize=(12, 9))
sns.scatterplot(data=filtered_data, x='Date', y='Active_Cases', hue='State')
plt.title("Top 5 affected States in India", size=19)
plt.show()

# %%
vaccine_data.head()
# Out:
#                 States  First_Dose  Second_Dose
# 0  Andaman And Nicobar      294001       200157
# 1       Andhra Pradesh    32976969     20375181
# 2    Arunachal Pradesh      771875       534486
# 3                Assam    20172463      8068795
# 4                Bihar    49874828     18346781

# %%
vaccine_data.rename(columns = {"First_Dose" :"First_Dose_vaccine"},inplace=True)

# %%
vaccine_data
# Out:
#                                       States  First_Dose_vaccine  Second_Dose
# 0                        Andaman And Nicobar              294001       200157
# 1                             Andhra Pradesh            32976969     20375181
# 2                          Arunachal Pradesh              771875       534486
# 3                                      Assam            20172463      8068795
# 4                                      Bihar            49874828     18346781
# 5                                 Chandigarh              926035       546981
# 6                               Chhattisgarh            14851682      7343273
# 7   Dadra And Nagar Haveli And Daman And Diu              660753       370255
# 8                                      Delhi            13055636      7425404
# 9                                        Goa             1262568       911114
# 10                                   Gujarat            44735217     25972387
# ...

# %%
vaccine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   States              36 non-null     object
#  1   First_Dose_vaccine  36 non-null     int64
#  2   Second_Dose         36 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 996.0+ bytes

# %%
data.isnull().sum()
# Out:
# Date              0
# State           181
# Region            0
# Confirmed         0
# Deaths            0
# Recovered         0
# Active_Cases      0
# dtype: int64

# %%
vaccine_data.isnull().sum()
# Out:
# Sr.No          0
# States         0
# First_Dose     0
# Second_Dose    0
# dtype: int64

# %%
vaccination = vaccine_data.drop(columns = ['Second_Dose'])

# %%
vaccination
# Out:
#                                       States  First_Dose_vaccine
# 0                        Andaman And Nicobar              294001
# 1                             Andhra Pradesh            32976969
# 2                          Arunachal Pradesh              771875
# 3                                      Assam            20172463
# 4                                      Bihar            49874828
# 5                                 Chandigarh              926035
# 6                               Chhattisgarh            14851682
# 7   Dadra And Nagar Haveli And Daman And Diu              660753
# 8                                      Delhi            13055636
# 9                                        Goa             1262568
# 10                                   Gujarat            44735217
# 11                                   Haryana            17772376
# 12                          Himachal Pradesh             5713695
# ...

# %%
# Data
data = {
    'States': ['Andaman And Nicobar', 'Andhra Pradesh', 'Assam', 'Bihar'],
    'First_Dose': [294001, 32976969, 20172463, 49874828],
    'Second_Dose': [200157, 20375181, 8068795, 18346781]
}

# Convert data into a DataFrame
df = pd.DataFrame(data)

# Plotting
plt.figure(figsize=(12, 6))

# Plotting pie chart for first dose
plt.subplot(1, 2, 1)
plt.pie(df['First_Dose'], labels=df['States'], autopct='%1.1f%%')
plt.title('Distribution of First Dose of Vaccination by State')

# Plotting pie chart for second dose
plt.subplot(1, 2, 2)
plt.pie(df['Second_Dose'], labels=df['States'], autopct='%1.1f%%')
plt.title('Distribution of Second Dose of Vaccination by State')

plt.tight_layout()
plt.show()

# %%
data.isnull()
# Out:
#       Date  State  Region  Confirmed  Deaths  Recovered
# 0    False   True   False      False   False      False
# 1    False   True   False      False   False      False
# 2    False   True   False      False   False      False
# 3    False   True   False      False   False      False
# 4    False   True   False      False   False      False
# ..     ...    ...     ...        ...     ...        ...
# 316  False  False   False      False   False      False
# 317  False  False   False      False   False      False
# 318  False  False   False      False   False      False
# 319  False  False   False      False   False      False
# 320  False  False   False      False   False      False
#
# [321 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
#2.
#import seaborn as sns
#import matplotlib.pyplot as plt
#sns.heatmap(data.isnull())
#plt.show()

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# # Show the number of Confirmed,Deaths and Recovered cases in ecah Regions

# %%
#data.groupby('Region').sum().head(2)
#data.groupby('Region')['Confirmed'].Sum().sort_values(ascending.False).head(20)
#data groupby('Region')['Confirmed','Recovered'].sum()

# %%
data.groupby('Region').sum()
# Out:
#                          Date State  Confirmed  Deaths  Recovered
# Region
# Afghanistan         4/29/2020     0       1939      60        252
# Albania             4/29/2020     0        766      30        455
# Algeria             4/29/2020     0       3848     444       1702
# Andorra             4/29/2020     0        743      42        423
# Angola              4/29/2020     0         27       2          7
# ...                       ...   ...        ...     ...        ...
# West Bank and Gaza  4/29/2020     0        344       2         71
# Western Sahara      4/29/2020     0          6       0          5
# Yemen               4/29/2020     0          6       0          1
# Zambia              4/29/2020     0         97       3         54
# Zimbabwe            4/29/2020     0         32       4          5
#
# [187 rows x 5 columns]

# %%
data.groupby('Region')[['Confirmed','Deaths','Recovered']].sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
data.groupby('Region').sum().head(20)
# Out:
#                                                                   Date  \
# Region
# Afghanistan                                                  4/29/2020
# Albania                                                      4/29/2020
# Algeria                                                      4/29/2020
# Andorra                                                      4/29/2020
# Angola                                                       4/29/2020
# Antigua and Barbuda                                          4/29/2020
# Argentina                                                    4/29/2020
# Armenia                                                      4/29/2020
# Australia            4/29/20204/29/20204/29/20204/29/20204/29/20204...
# Austria                                                      4/29/2020
# Azerbaijan                                                   4/29/2020
# Bahamas                                                      4/29/2020
# ...

# %%
data.groupby('Region')[['Confirmed','Deaths','Recovered']].sum().head(20)
# Out:
#                      Confirmed  Deaths  Recovered
# Region
# Afghanistan               1939      60        252
# Albania                    766      30        455
# Algeria                   3848     444       1702
# Andorra                    743      42        423
# Angola                      27       2          7
# Antigua and Barbuda         24       3         11
# Argentina                 4285     214       1192
# Armenia                   1932      30        900
# Australia                 6752      91       5715
# Austria                  15402     580      12779
# Azerbaijan                1766      23       1267
# Bahamas                     80      11         23
# Bahrain                   2921       8       1455
# Bangladesh                7103     163        150
# Barbados                    80       7         39
# Belarus                  13181      84       2072
# Belgium                  47859    7501      11283
# Belize                      18       2          9
# ...

# %%
data.groupby('Region')['Confirmed'].sum()
# Out:
# Region
# Afghanistan           1939
# Albania                766
# Algeria               3848
# Andorra                743
# Angola                  27
#                       ...
# West Bank and Gaza     344
# Western Sahara           6
# Yemen                    6
# Zambia                  97
# Zimbabwe                32
# Name: Confirmed, Length: 187, dtype: int64

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False)
# Out:
# Region
# US                       1039909
# Spain                     236899
# Italy                     203591
# France                    166543
# UK                        166441
#                           ...
# Sao Tome and Principe          8
# Papua New Guinea               8
# Bhutan                         7
# Western Sahara                 6
# Yemen                          6
# Name: Confirmed, Length: 187, dtype: int64

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending=True).head(10)
# Out:
# Region
# Yemen                     6
# Western Sahara            6
# Bhutan                    7
# Papua New Guinea          8
# Sao Tome and Principe     8
# Mauritania                8
# MS Zaandam                9
# Gambia                   10
# Holy See                 10
# Suriname                 10
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region')[['Confirmed','Recovered']].sum()
# Out:
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %% [markdown]
# #  Remove all the records where Confirmed Cases is Less than 10

# %%
#data.Confirmed<10
#data[data.Confirm < 10]
#df

# %%
data.Confirmed<10
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 316    False
# 317    False
# 318    False
# 319    False
# 320    False
# Name: Confirmed, Length: 321, dtype: bool

# %%
data[data.Confirmed<10]
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %%
data[~(data.Confirmed<10)]
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data= data[~(data.Confirmed <10)]

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
data=data[~(data.Confirmed<10)]  # remove the records satisfying the perticular codition

# %%
data.head(20)
# Out:
#          Date State                  Region  Confirmed  Deaths  Recovered
# 0   4/29/2020   NaN             Afghanistan       1939      60        252
# 1   4/29/2020   NaN                 Albania        766      30        455
# 2   4/29/2020   NaN                 Algeria       3848     444       1702
# 3   4/29/2020   NaN                 Andorra        743      42        423
# 4   4/29/2020   NaN                  Angola         27       2          7
# 5   4/29/2020   NaN     Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN               Argentina       4285     214       1192
# 7   4/29/2020   NaN                 Armenia       1932      30        900
# 8   4/29/2020   NaN                 Austria      15402     580      12779
# 9   4/29/2020   NaN              Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN                 Bahamas         80      11         23
# 11  4/29/2020   NaN                 Bahrain       2921       8       1455
# ...

# %% [markdown]
# #  In Which Region,maximum number of Confirmed cases were recorded?

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region').Confirmed.sum().sort_values(ascending= False)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Sweden              20302
# Ireland             20253
# Mexico              17799
# Israel              15834
# Singapore           15641
# Pakistan            15525
# Austria             15402
# Chile               14885
# Japan               13895
# Belarus             13181
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region').Confirmed.sum().sort_values(ascending= False).head(30)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Sweden              20302
# Ireland             20253
# Mexico              17799
# Israel              15834
# Singapore           15641
# Pakistan            15525
# Austria             15402
# Chile               14885
# Japan               13895
# Belarus             13181
# Name: Confirmed, dtype: int64

# %% [markdown]
# #  In which Region,minimum number of Deaths cases were recorded?

# %%
data.groupby('Region').Deaths.sum()
# Out:
# Region
# Afghanistan            60
# Albania                30
# Algeria               444
# Andorra                42
# Angola                  2
#                      ...
# West Bank and Gaza      2
# Western Sahara          0
# Yemen                   0
# Zambia                  3
# Zimbabwe                4
# Name: Deaths, Length: 187, dtype: int64

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending=True).head(50)
# Out:
# Region
# Laos                                0
# Mongolia                            0
# Mozambique                          0
# Cambodia                            0
# Fiji                                0
# Namibia                             0
# Nepal                               0
# Madagascar                          0
# Macau                               0
# Papua New Guinea                    0
# Rwanda                              0
# Saint Kitts and Nevis               0
# Bhutan                              0
# Dominica                            0
# Central African Republic            0
# Saint Lucia                         0
# Holy See                            0
# Sao Tome and Principe               0
# Yemen                               0
# Western Sahara                      0
# Eritrea                             0
# Vietnam                             0
# Saint Vincent and the Grenadines    0
# Timor-Leste                         0
# ...

# %% [markdown]
# # How many Confirmed,Deaths & Recovered cases were reported form India till 29 April 2020?

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.Region == 'India'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 316    False
# 317    False
# 318    False
# 319    False
# 320    False
# Name: Region, Length: 321, dtype: bool

# %%
data[data.Region == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
data[data.Region == 'US']
# Out:
#           Date                         State Region  Confirmed  Deaths  \
# 181  4/29/2020                       Alabama     US       6912     256
# 182  4/29/2020                        Alaska     US        355       9
# 186  4/29/2020                       Arizona     US       7209     308
# 187  4/29/2020                      Arkansas     US       3193      57
# 195  4/29/2020                    California     US      48747    1946
# 199  4/29/2020                      Colorado     US      14758     766
# 200  4/29/2020                   Connecticut     US      26767    2169
# 202  4/29/2020                      Delaware     US       4655     144
# 204  4/29/2020  Diamond Princess cruise ship     US         49       0
# 205  4/29/2020          District of Columbia     US       4106     205
# 208  4/29/2020                       Florida     US      33193    1218
# 213  4/29/2020                       Georgia     US      25775    1101
# ...

# %% [markdown]
# # Sort the entire data wrt No.of Confirmed cases in ascending order

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.sort_values(by = ['Confirmed'],ascending =True).head(50)
# Out:
#           Date                             State  \
# 285  4/29/2020                         Recovered
# 284  4/29/2020                         Recovered
# 203  4/29/2020      Diamond Princess cruise ship
# 305  4/29/2020                             Tibet
# 289  4/29/2020         Saint Pierre and Miquelon
# 184  4/29/2020                          Anguilla
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba
# 272  4/29/2020             Northwest Territories
# 288  4/29/2020                  Saint Barthelemy
# 178  4/29/2020                               NaN
# 194  4/29/2020            British Virgin Islands
# 177  4/29/2020                               NaN
# 18   4/29/2020                               NaN
# 126  4/29/2020                               NaN
# 140  4/29/2020                               NaN
# 105  4/29/2020                               NaN
# 98   4/29/2020                               NaN
# 156  4/29/2020                               NaN
# ...

# %% [markdown]
# # Sort the entire wrt No.of Recovered cases in decending order

# %%
data.sort_values(by = ['Recovered'],ascending = False)
# Out:
#           Date           State   Region  Confirmed  Deaths  Recovered
# 153  4/29/2020             NaN    Spain     236899   24275     132929
# 285  4/29/2020       Recovered       US          0       0     120720
# 61   4/29/2020             NaN  Germany     161539    6467     120400
# 76   4/29/2020             NaN     Iran      93657    5957      73791
# 80   4/29/2020             NaN    Italy     203591   27682      71252
# ..         ...             ...      ...        ...     ...        ...
# 248  4/29/2020        Maryland       US      20849    1078          0
# 246  4/29/2020        Manitoba   Canada        275       6          0
# 243  4/29/2020       Louisiana       US      27660    1845          0
# 241  4/29/2020        Kentucky       US       4537     234          0
# 215  4/29/2020  Grand Princess   Canada         13       0          0
#
# [321 rows x 6 columns]

# %%
data.sort_values(by = ['Recovered'],ascending = False).head(50)
# Out:
#           Date            State                Region  Confirmed  Deaths  \
# 153  4/29/2020              NaN                 Spain     236899   24275
# 285  4/29/2020        Recovered                    US          0       0
# 61   4/29/2020              NaN               Germany     161539    6467
# 76   4/29/2020              NaN                  Iran      93657    5957
# 80   4/29/2020              NaN                 Italy     203591   27682
# 229  4/29/2020            Hubei        Mainland China      68128    4512
# 57   4/29/2020              NaN                France     165093   24087
# 167  4/29/2020              NaN                Turkey     117589    3081
# 22   4/29/2020              NaN                Brazil      79685    5513
# 158  4/29/2020              NaN           Switzerland      29407    1716
# 284  4/29/2020        Recovered                Canada          0       0
# 78   4/29/2020              NaN               Ireland      20253    1190
# ...

# %%
data.tail()
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263

# %%
data.describe()
# Out:
#            Confirmed        Deaths      Recovered
# count     321.000000    321.000000     321.000000
# mean     9949.800623    709.152648    3030.277259
# std     31923.853086   3236.162817   14364.870365
# min         0.000000      0.000000       0.000000
# 25%       104.000000      2.000000       2.000000
# 50%       653.000000     12.000000      73.000000
# 75%      4655.000000    144.000000     587.000000
# max    299691.000000  27682.000000  132929.000000

# %%
data.drop(['S. No.'],axis=1,inplace=True)

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]
